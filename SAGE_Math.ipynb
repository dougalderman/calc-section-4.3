# %%
#Problem 37

# %%
x = var('x')

# %%
def f(x): return x^4 - x^2

# %%
p = []

# %%
p.append(plot(f(x),(x,-3/2,-1), color='blue'))

# %%
p.append(plot(f(x),(x,-1,1), color='blue', fill=true, legend_label='f(x)'))

# %%
p.append(plot(f(x),(x,1,3/2), color='blue'))

# %%
sum(p)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
int = integral(f(x), x, -1, 1)

# %%
int
# Out:
# -4/15

# %%
#Problem 109

# %%
x = var('x')

# %%
def f(x): return 3 + sqrt(1-x^2)

# %%
plot(f(x),(x,-1, 1), color='blue', legend_label='f(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
int = integral(f(x), x, -1, 1)

# %%
int
# Out:
# 1/2*pi + 6

# %%
numerical_approx(int)
# Out:
# 7.57079632679490

# %%
#Problem 113

# %%
x = var('x')

# %%
def f(x): return 8 / (x^2 + 4)

# %%
p = []

# %%
p.append(plot(f(x),(x,-15,-10), color='blue'))

# %%
p.append(plot(f(x),(x,-10, 10), color='blue', fill=true, legend_label='f(x)'))

# %%
p.append(plot(f(x),(x,10,15), color='blue'))

# %%
sum(p)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
int = integral(f(x), x, -10, 10)

# %%
int
# Out:
# 8*arctan(5)

# %%
numerical_approx(int)
# Out:
# 10.9872061355601
